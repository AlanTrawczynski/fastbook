# %% [markdown]
# # Feline classifier

# %% [markdown]
# Classifies a feline image into one of the following categories:
# - Cat
# - Lion
# - Tiger
# - Panther
# - Leopard

# %%
# !pip install -Uqq fastbook
from fastbook import *
from fastai.vision.widgets import *

# %%
path = Path()
path.ls(file_exts='.pkl')
learn_inf = load_learner(path/'export.pkl')

# %%
btn_upload = widgets.FileUpload()
lbl_pred = widgets.Label()
out_pl = widgets.Output()

def on_upload(_):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(256))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
btn_upload.observe(on_upload, names='data')

VBox([widgets.Label('Select a feline!'), 
      btn_upload, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select a feline!'), FileUpload(value={}, description='Upload'), Output(), Label(va…
